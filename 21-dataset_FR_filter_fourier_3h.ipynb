# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
# import statsmodels.api as sm
# from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy import fftpack

# %% [markdown]
# # Objectif du notebook
#
# A partir du dataset original, suivant la période retenue, le notebook a pour objectif d'épurer le signal des variables à expliquer au moyen de la transformation de Fourier. Il s'agit de supprimer le bruit du signal en ne prenant pas en compte les plus petites amplitudes. De nombreuses fréquences sont ainsi écartées sans perte importante d'information.
#
# L'objectif sera d'aider les modèles à obtenir une bonne performance.

# %%
# Import du fichier correspondant à la période de 3H
df = pd.read_csv('./dataset/France_3H.csv')
df.head(1)
# Out:
#                  Dates  Consommation  Thermique  Nucléaire  Eolien  Solaire  \
# 0  2013-01-01 00:00:00       57831.6     3706.0    50218.2  3975.8      0.0
#
#    Hydraulique  Pompage  Bioénergies  Balance
# 0       6770.8   -791.6        754.8   6802.4

# %%
france = df[['Dates']]

# %% [markdown]
# # Balance

# %%
data = df['Balance'].values

# %%
df['Balance'].to_csv('fourier.csv', sep=';')

# %%
plt.figure(figsize=(16, 6))
plt.plot(data)
plt.title('Balance originale');

# %%
# Spectre du signal
fourier = fftpack.fft(data)
frequences = fftpack.fftfreq(data.size)
power = np.abs(fourier)
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), power)
plt.title('Spectre Balance')
plt.ylim((0, 2e7))
plt.grid();

# %%
# Elimination du bruit
filtre = 0.3e7
fourier[power < filtre] = 0
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), np.abs(fourier))
plt.title('Spectre Balance épuré')
plt.ylim((0, 2e7))
plt.grid();

# %%
# Reconstitution du signal
filtered_data = fftpack.ifft(fourier)
plt.figure(figsize=(16, 6))
plt.plot(data, alpha = 0.5)
plt.plot(filtered_data, color = 'g', alpha = 0.5)
plt.title('Balance épurée')
plt.axhline(0, color = 'r')
plt.savefig('./png/signal_var_balance_3h.png');
# Out:
# C:\Python\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
france['Balance'] = filtered_data.tolist()
# Out:
# <ipython-input-9-9eaf66574dab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   france['Balance'] = filtered_data.tolist()

# %% [markdown]
# # Consommation

# %%
data = df['Consommation'].values

# %%
plt.figure(figsize=(16, 6))
plt.plot(data)
plt.title('Consommation originale');

# %%
# Spectre du signal
fourier = fftpack.fft(data)
frequences = fftpack.fftfreq(data.size)
power = np.abs(fourier)
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), power)
plt.title('Spectre Consommation')
plt.ylim((0, 1e8))
plt.grid();

# %%
# Elimination du bruit
filtre = 0.6e7
fourier[power < filtre] = 0
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), np.abs(fourier))
plt.title('Spectre Consommation épuré')
plt.ylim((0, 1e8))
plt.grid();

# %%
# Reconstitution du signal
filtered_data = fftpack.ifft(fourier)
plt.figure(figsize=(16, 6))
plt.plot(data, alpha = 0.5)
plt.plot(filtered_data, color = 'g', alpha = 0.5)
plt.title('Consommation épurée')
plt.axhline(0, color = 'r')
plt.savefig('./png/signal_var_consommation_3h.png');
# Out:
# C:\Python\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
france['Consommation'] = filtered_data.tolist()
# Out:
# <ipython-input-15-2cd26e90e1cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   france['Consommation'] = filtered_data.tolist()

# %% [markdown]
# # Production éolienne

# %%
data = df['Eolien'].values

# %%
plt.figure(figsize=(16, 6))
plt.plot(data)
plt.title('Eolien originale');

# %%
# Spectre du signal
fourier = fftpack.fft(data)
frequences = fftpack.fftfreq(data.size)
power = np.abs(fourier)
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), power)
plt.title('Spectre Eolien')
plt.ylim((0, 1e7))
plt.grid();

# %%
# Elimination du bruit
filtre = 0.01e7
fourier[power < filtre] = 0
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), np.abs(fourier))
plt.title('Spectre Eolien épuré')
plt.ylim((0, 1e7))
plt.grid();

# %%
# Reconstitution du signal
filtered_data = fftpack.ifft(fourier)
plt.figure(figsize=(16, 6))
plt.plot(data, alpha = 0.5)
plt.plot(filtered_data, color = 'g', alpha = 0.5)
plt.title('Eolien épurée')
plt.axhline(0, color = 'r')
plt.savefig('./png/signal_var_eolien_3h.png');
# Out:
# C:\Python\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
france['Eolien'] = filtered_data.tolist()
# Out:
# <ipython-input-21-846e8f16ba31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   france['Eolien'] = filtered_data.tolist()

# %% [markdown]
# # Production solaire

# %%
data = df['Solaire'].values

# %%
plt.figure(figsize=(16, 6))
plt.plot(data)
plt.title('Solaire originale');

# %%
# Spectre du signal
fourier = fftpack.fft(data)
frequences = fftpack.fftfreq(data.size)
power = np.abs(fourier)
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), power)
plt.title('Spectre Solaire')
plt.ylim((0, 1e7))
plt.grid();

# %%
# Elimination du bruit
filtre = 0.02e7
fourier[power < filtre] = 0
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), np.abs(fourier))
plt.title('Spectre Solaire épuré')
plt.ylim((0, 1e7))
plt.grid();

# %%
# Reconstitution du signal
filtered_data = fftpack.ifft(fourier)
plt.figure(figsize=(16, 6))
plt.plot(data, alpha = 0.5)
plt.plot(filtered_data, color = 'g', alpha = 0.5)
plt.title('Solaire épurée')
plt.axhline(0, color = 'r')
plt.savefig('./png/signal_var_solaire_3h.png');
# Out:
# C:\Python\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
france['Solaire'] = filtered_data.tolist()
# Out:
# <ipython-input-27-948e0575376e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   france['Solaire'] = filtered_data.tolist()

# %% [markdown]
# # Production Hydraulique

# %%
data = df['Hydraulique'].values

# %%
plt.figure(figsize=(16, 6))
plt.plot(data)
plt.title('Hydraulique originale');

# %%
# Spectre du signal
fourier = fftpack.fft(data)
frequences = fftpack.fftfreq(data.size)
power = np.abs(fourier)
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), power)
plt.title('Spectre Hydraulique')
plt.ylim((0, 1e7))
plt.grid()
plt.savefig('./png/spectre_var_hydraulique.png');

# %%
# Elimination du bruit
filtre = 0.03e7
fourier[power < filtre] = 0
plt.figure(figsize=(16, 6))
plt.plot(np.abs(frequences), np.abs(fourier))
plt.title('Spectre Hydraulique épuré')
plt.ylim((0, 1e7))
plt.grid()
plt.savefig('./png/spectre_var_hydraulique_filtré.png');

# %%
# Reconstitution du signal
filtered_data = fftpack.ifft(fourier)
plt.figure(figsize=(16, 6))
plt.plot(data, alpha = 0.5)
plt.plot(filtered_data, color = 'g', alpha = 0.5)
plt.title('Hydraulique épurée')
plt.axhline(0, color = 'r')
plt.savefig('./png/signal_var_hydraulique_3h.png');
# Out:
# C:\Python\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
france['Hydraulique'] = filtered_data.tolist()
# Out:
# <ipython-input-33-069c6645cab2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   france['Hydraulique'] = filtered_data.tolist()

# %%
france.set_index('Dates', inplace = True)
france = france.astype(float)
france.head(1)
# Out:
# C:\Python\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:995: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
#                          Balance  Consommation       Eolien    Solaire  \
# Dates
# 2013-01-01 00:00:00  5793.132541  56094.121228  5085.207663  73.165713
#
#                      Hydraulique
# Dates
# 2013-01-01 00:00:00   3697.02044

# %%
france.to_csv('./dataset/France_3H_filtered.csv')
